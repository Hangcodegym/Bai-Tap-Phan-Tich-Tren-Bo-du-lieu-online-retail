# %% [markdown]
# # 1. Đọc bộ dữ liệu

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('OnlineRetail.csv', header=0, encoding='ISO-8859-1')
display(df)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ##  cho biết số dòng, số cột và kiểu dữ liệu của các thuộc tính.

# %%
print(f'Bộ dữ liệu có số dòng là: {df.shape[0]}, số cột là: {df.shape[1]}')
# Out:
# Bộ dữ liệu có số dòng là: 541909, số cột là: 8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# # 2. Trích xuất dữ liệu các cột Description và Quantity lưu vào file OnlineRetail.csv

# %%
df1=df.loc[:, ['Description', 'Quantity']]
display(df1)
# Out:
#                                 Description  Quantity
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6
# 1                       WHITE METAL LANTERN         6
# 2            CREAM CUPID HEARTS COAT HANGER         8
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4            RED WOOLLY HOTTIE WHITE HEART.         6
# ...                                     ...       ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12
# 541905         CHILDREN'S APRON DOLLY GIRL          6
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908        BAKING SET 9 PIECE RETROSPOT          3
#
# [541909 rows x 2 columns]

# %%
df1.to_csv('OnlineRetail2.csv')

# %% [markdown]
# # 3 .Trích xuất dữ liệu 1000 dòng đầu tiên lưu vào file OnlineRetail.xlsx

# %%
import pandas as pd
import numpy as np
df2=pd.read_csv('OnlineRetail.csv', header=0, encoding='ISO-8859-1')
display(df2.head(1000))
# Out:
#      Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0             0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1             1    536365     71053                  WHITE METAL LANTERN
# 2             2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3             3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4             4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ..          ...       ...       ...                                  ...
# 995         995    536520     22469                HEART OF WICKER SMALL
# 996         996    536520     22100             SKULLS SQUARE TISSUE BOX
# 997         997    536520     22096      PINK PAISLEY SQUARE TISSUE BOX
# 998         998    536520     22583         PACK OF 6 HANDBAG GIFT BOXES
# 999         999    536520     21358           TOAST ITS - HAPPY BIRTHDAY
#
#      Quantity      InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df2.to_excel('OnlineRetail3.xlsx')

# %% [markdown]
# # 4. Trích xuất các bản ghi có số lượng từ 10 trở lên lưu vào file OnlineRetail.h5

# %%
df3=df[(df['Quantity']>10 )]
display(df3)
# Out:
#         Unnamed: 0 InvoiceNo StockCode                      Description  \
# 9                9    536367     84879    ASSORTED COLOUR BIRD ORNAMENT
# 26              26    536370     22728        ALARM CLOCK BAKELIKE PINK
# 27              27    536370     22727        ALARM CLOCK BAKELIKE RED
# 28              28    536370     22726       ALARM CLOCK BAKELIKE GREEN
# 29              29    536370     21724  PANDA AND BUNNIES STICKER SHEET
# ...            ...       ...       ...                              ...
# 541894      541894    581587     22631         CIRCUS PARADE LUNCH BOX
# 541895      541895    581587     22556   PLASTERS IN TIN CIRCUS PARADE
# 541896      541896    581587     22555        PLASTERS IN TIN STRONGMAN
# 541902      541902    581587     22629              SPACEBOY LUNCH BOX
# 541904      541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS
#
#         Quantity      InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df3.to_hdf('OnlineRetail.h5', 'table')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_25728\624663657.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['InvoiceNo', 'StockCode', 'Description', 'InvoiceDate', 'Country'], dtype='object')]
#
#   df3.to_hdf('OnlineRetail.h5', 'table')

# %% [markdown]
# # 5. Trích xuất dữ liệu các phần tử từ dòng 1000 đến dòng 2000, các cột Quantity, InvoiceDate, UnitPrice lưu vào file OnlineRetail.json

# %%
df4=df.loc[1000:2000, 'Quantity':'UnitPrice']
display(df4)
# Out:
#       Quantity      InvoiceDate  UnitPrice
# 1000         1  12/1/2010 12:43       1.25
# 1001         1  12/1/2010 12:43       1.25
# 1002         1  12/1/2010 12:43       1.25
# 1003         1  12/1/2010 12:43       1.25
# 1004        12  12/1/2010 12:43       0.29
# ...        ...              ...        ...
# 1996         1  12/1/2010 14:34       2.95
# 1997         3  12/1/2010 14:34       1.65
# 1998         1  12/1/2010 14:34       4.95
# 1999         1  12/1/2010 14:34       2.95
# 2000         2  12/1/2010 14:34       1.25
#
# [1001 rows x 3 columns]

# %%
df4.to_json('OnlineRetail.json',orient='columns')

# %% [markdown]
# # 6. Trích xuất các bản ghi có số hóa đơn ‘536365’ lưu vào file OnlineRetail.html

# %%
df5=df[df['InvoiceNo']=='536365' ]
display(df5)
# Out:
#    Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0           0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1    536365     71053                  WHITE METAL LANTERN
# 2           2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# 5           5    536365     22752         SET 7 BABUSHKA NESTING BOXES
# 6           6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER
#
#    Quantity     InvoiceDate  UnitPrice  CustomerID         Country
# 0         6  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1         6  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2         8  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3         6  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %%
df5.to_html('OnlineRetail.html')
